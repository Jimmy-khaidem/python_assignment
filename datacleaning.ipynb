# %%
import pandas as pd
file=pd.read_csv("S:/Aroha_tech/assignmentQ/python/P4-Demographic-Data.csv")
import numpy as np

# %%
df=pd.DataFrame(file)
df.drop_duplicates(subset='Income Group')
# Out:
#   Country Name Country Code  Birth rate  Internet users         Income Group
# 0        Aruba          ABW      10.244            78.9          High income
# 1  Afghanistan          AFG      35.253             5.9           Low income
# 2       Angola          AGO      45.985            19.1  Upper middle income
# 6      Armenia          ARM      13.308            41.9  Lower middle income

# %%
df.drop_duplicates(subset='Birth rate')
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
pd.isnull(df['Birth rate'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: Birth rate, Length: 195, dtype: bool

# %%
df['Income Group']=df['Income Group'].replace(to_replace='Low income',value=np.nan)

# %%
df['Internet users']=df['Internet users'].replace(to_replace=57.2,value=np.nan)

# %%
df
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877             NaN
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1                    NaN
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
df['Internet users'].fillna(df['Internet users'].mean(),inplace=True)

# %%
df['Income Group'].fillna(method='ffill',inplace=True)

# %%
newdf=df.loc[df['Income Group']!='High income']
newdf
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 2              Angola          AGO      45.985       19.100000
# 3             Albania          ALB      12.877       41.998515
# 6             Armenia          ARM      13.308       41.900000
# 10         Azerbaijan          AZE      18.300       58.700000
# 11            Burundi          BDI      44.151        1.300000
# ..                ...          ...         ...             ...
# 190       Yemen, Rep.          YEM      32.947       20.000000
# 191      South Africa          ZAF      20.850       46.500000
# 192  Congo, Dem. Rep.          COD      42.394        2.200000
# 193            Zambia          ZMB      40.471       15.400000
# 194          Zimbabwe          ZWE      35.715       18.500000
#
#             Income Group
# 2    Upper middle income
# 3    Upper middle income
# 6    Lower middle income
# 10   Upper middle income
# 11   Upper middle income
# ..                   ...
# ...

# %%
newdf.drop_duplicates(subset='Internet users',inplace=False)
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 2              Angola          AGO      45.985       19.100000
# 3             Albania          ALB      12.877       41.998515
# 6             Armenia          ARM      13.308       41.900000
# 10         Azerbaijan          AZE      18.300       58.700000
# 11            Burundi          BDI      44.151        1.300000
# ..                ...          ...         ...             ...
# 189             Samoa          WSM      26.172       15.300000
# 191      South Africa          ZAF      20.850       46.500000
# 192  Congo, Dem. Rep.          COD      42.394        2.200000
# 193            Zambia          ZMB      40.471       15.400000
# 194          Zimbabwe          ZWE      35.715       18.500000
#
#             Income Group
# 2    Upper middle income
# 3    Upper middle income
# 6    Lower middle income
# 10   Upper middle income
# 11   Upper middle income
# ..                   ...
# ...

# %%
newdf['Birth rate'].dtypes
# Out:
# dtype('float64')

# %%
newdf['Birth rate']=newdf['Birth rate'].astype({'Birth rate':int})

# %%
newdf['Internet users']=pd.to_numeric(newdf['Internet users'])

# %%
newdf.dtypes
# Out:
# Country Name      object
# Country Code      object
# Birth rate         int32
# Internet users     int32
# Income Group      object
# dtype: object

# %%
newdf['Internet users']=newdf['Internet users'].astype(int)

# %%
newdf.dtypes
# Out:
# Country Name      object
# Country Code      object
# Birth rate         int32
# Internet users     int32
# Income Group      object
# dtype: object

# %%
newdf1=newdf.drop_duplicates(subset=['Birth rate'],keep='last')

# %%
newdf1
# Out:
#                        Country Name Country Code  Birth rate  Internet users  \
# 24                           Brazil          BRA          14              51
# 83                             Iraq          IRQ          31               9
# 97                          Lao PDR          LAO          27              12
# 98                          Lebanon          LBN          13              70
# 110                         Moldova          MDA          12              45
# 115                            Mali          MLI          44               4
# 122                       Mauritius          MUS          10              39
# 135                        Pakistan          PAK          29              11
# 138                     Philippines          PHL          23              37
# 139                Papua New Guinea          PNG          28               6
# 146                         Romania          ROU           8              50
# ...

# %%
newdf2=newdf1[newdf1['Country Code'].str.startswith('S')]

# %%
newdf2
# Out:
#               Country Name Country Code  Birth rate  Internet users  \
# 150                  Sudan          SDN          33              23
# 151                Senegal          SEN          38              13
# 155            El Salvador          SLV          17              23
# 157                 Serbia          SRB           9              52
# 158            South Sudan          SSD          37              14
# 159  Sao Tome and Principe          STP          34              23
# 160               Suriname          SUR          18              37
# 166   Syrian Arab Republic          SYR          24              26
#
#             Income Group
# 150  Lower middle income
# 151  Lower middle income
# 155  Lower middle income
# 157  Upper middle income
# 158  Upper middle income
# 159  Lower middle income
# 160  Upper middle income
# 166  Lower middle income

# %%
newdf2.sort_values(['Internet users'],ascending=False).head(3)
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 157                Serbia          SRB           9              52
# 160              Suriname          SUR          18              37
# 166  Syrian Arab Republic          SYR          24              26
#
#             Income Group
# 157  Upper middle income
# 160  Upper middle income
# 166  Lower middle income
